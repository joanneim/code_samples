# %% [markdown]
# <a href="https://colab.research.google.com/github/joanneim/code_samples/blob/main/api_pull_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About the Google Knowedge Graph API
#
# *   Payment/API query quota: The Knowledge Graph API Search API allows developers a free quota of up to 100,000 (one hundred thousand) read calls per day per project
#
# *   A useful primer can be found here: https://searchengineland.com/
# laymans-visual-guide-googles-knowledge-graph-search-api-241935
#
# *   The test GUI can be found here:
# https://developers.google.com/knowledge-graph/reference/rest/v1/?apix=true

# %% [markdown]
# # Code

# %%
# !pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (2.0.1)

# %%
# Dependencies
# %%capture
from __future__ import print_function
import json
import urllib
import pandas as pd
import time
from google.colab import drive
import urllib.request

# %%
# DO NOT SHARE. IF YOU SEE THIS AND YOU ARE NOT ME KINDLY NOTIFY AUTHOR IMMEDIATELY.
api_key = API_KEY

# %%
INPUT_FILE_NAME  = "notickers_sellers.xlsx"
OUTPUT_FILE_NAME = "notickers_sellers_out.xlsx"

# %%
# Mount Google Drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify entity type, which is required in query to Google's Knowledge Graph
# param_entitytype in ["Corporation", "Entity", "Organization", "Thing", "Place"]

param_entitytype = "Entity"

# %%
# Import excel spradsheet of parent company names that was generated from STATA code
df = pd.read_excel("/content/drive/My Drive/OwnershipPatterns/data_in/" + INPUT_FILE_NAME)
print(df.columns)
# Out:
# Index(['sellername', 'sellername_first', 'sellername_second'], dtype='object')

# %%
# Extract 'Key people' field from company page infobar;
google_v =  ['google_name', 'google_score', 'google_url']
global fields
fields = ['Formerly', 'Defunct', 'Fate' , 'Successor', 'Parent', 'Type', 'Traded as', 'Industry', 'ISIN', 'Headquarters', 'Area served', 'Total assets', 'Net income', 'Operating income', 'Total equity', 'Number of employees']
for f in google_v + fields:
  df.insert(loc = 0, column = f, value = ['' for i in range(df.shape[0])])

# %%
# Example query
query = "Linde Plc"
param_entitytype = "Corporation"
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'query': query,
    'limit': 1,
    'indent': True,
    'key': api_key,
    'types': param_entitytype
}
url = service_url + '?' + urllib.parse.urlencode(params)
response = json.loads(urllib.request.urlopen(url).read())
print(response)
# Out:
# {'@context': {'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'EntitySearchResult': 'goog:EntitySearchResult', 'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': [{'@type': 'EntitySearchResult', 'result': {'@type': ['Organization', 'Thing', 'Corporation'], 'description': 'Chemicals company', 'image': {'url': 'https://commons.wikimedia.org/wiki/File:Linde_plc.jpg', 'contentUrl': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRjoogaxC8b6zC0G4wF1TCVtErzDLIdX1b65nW0u_qev5czRH1P'}, '@id': 'kg:/g/1234zd1f', 'name': 'Linde plc', 'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Linde_plc', 'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License', 'articleBody': "Linde plc is a global multinational chemical company founded in Germany and, since 2018, domiciled in Ireland and headquartered in the United Kingdom. Linde is the world's largest industrial gas company by market share and revenue. "}}, 'resultScore': 7406.92236328125}]}

# %%
def _empty(x):

  ''' evaluates whether input is empty '''

  try:
    status = (x==None)
  except:
    pass

  if status==False:
    try:
      status = (pd.isnull(x))
    except:
      pass

  if status==False:
    try:
      status = len(x)==0
    except:
      pass

  if status==False:
    try:
      status = x==""
    except:
      pass

  if status==False:
    try:
      status = (pd.isna(x))
    except:
      pass

  if status==False:
    try:
      status = (x=="nan")
    except:
      pass

  if status==False:
    return False
  else:
    return True

# %%
def gk_wiki_data_extractor(i, df_field = "stn_name", df_type = "Entity"):
  '''
  Preamble: This function systematicaly extracts firm level data from Google's Knowlege Graph
  Inputs:
    - row i of dataframe with firm names
    - df_field: dataframe field containing firm name
    - df_type: param_entitytype, which can be one of the following ["Corporation", "Entity", "Organization", "Thing", "Place"]
  '''

  query = df.loc[i, df_field]
  param_entitytype = df_type
  service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
  params = {
      'query': query,
      'limit': 1,
      'indent': True,
      'key': api_key,
      'types': param_entitytype
  }


  url = service_url + '?' + urllib.parse.urlencode(params)
  try:
    response = json.loads(urllib.request.urlopen(url).read())
  except:
    return

  if len(response['itemListElement'])>0:

    for item in response['itemListElement'][0]['result']:

      name = response['itemListElement'][0]['result']['name']
      score = response['itemListElement'][0]['resultScore']

      try:
        url = response['itemListElement'][0]['result']['detailedDescription']['url']

        df.loc[i, 'google_name'], df.loc[i, 'google_score'], df.loc[i, 'google_url'] = name, score, url


        ## get wiki data ##

        infobar = pd.read_html(url)
        df_wiki = infobar[0]

        if len(df_wiki.columns) == 2:
            df_wiki.columns = ['columns', 'data']
            # most output tables have 2 elements
        else:
            df_wiki.columns = ['columns', 'data', 'trash']
            df_wiki.drop(columns = 'trash', inplace = True)
            # sometimes the table output has 3 elements

        # some table cleaning is needed before transposing
        df_wiki.set_index(df_wiki['columns'], inplace = True)
        df_wiki.drop(columns = 'columns', inplace = True)
        df_wiki = df_wiki.transpose()
        # fields
        for f in fields:
          if f in df_wiki.columns:
            df.loc[i, f] = df_wiki[f][0]

        return
      except:
        pass

# %%
def wiki_data_extractor(i, df_field):
  '''
  Preamble: This function systematicaly extracts firm level data from Wikipedia
  Inputs:
  - row i of dataframe with firm names
  - df_field: dataframe field containing firm name
  '''
    try:

      # Must properly capitalize the name
      wiki_url = "https://en.wikipedia.org/wiki/" + df.loc[i, df_field].replace(" ", "_")

      df.loc[i, 'google_name'] , df.loc[i, 'google_url'] = df.loc[i, df_field] ,  wiki_url
      infobar = pd.read_html(wiki_url)

      for k in range(2):

        if _empty(df.loc[i,'Traded as'])==True:
          # Sometimes the infobar is infobar[0]; sometimes, infobar[2]
          df_wiki = infobar[k]
          if len(df_wiki.columns) == 2:
              df_wiki.columns = ['columns', 'data']
              # most output tables have 2 elements
          else:
              df_wiki.columns = ['columns', 'data', 'trash']
              df_wiki.drop(columns = 'trash', inplace = True)
              # sometimes the table output has 3 elements

          # some table cleaning is needed before transposing
          df_wiki.set_index(df_wiki['columns'], inplace = True)
          df_wiki.drop(columns = 'columns', inplace = True)
          df_wiki = df_wiki.transpose()
          # fields
          for f in fields:
            if f in df_wiki.columns:
              df.loc[i, f] = df_wiki[f][0]

    except:
        pass

# %%
"""Python client calling Knowledge Graph Search API."""

"""
    Preamble: The excel spreadsheet records around 4, 759 unique entities.
    For each entry, this script submits a Knowledge Graph query and extracts
    the first result that is an Organization.

    Code runs for approximately five minutes.

"""

for i in range(0, df.shape[0]):
#for i in range(1791, 2338):
#for i in range(1791, 1800):
#for i in range(1648, 1652):
  #for i in range(1500, df.shape[0]):

  # Iteration number
  print(i)

  # Tri wiki directly
  if _empty(df.loc[i, 'Traded as'])==True:
    wiki_data_extractor(i, "sellername")


    if _empty(df.loc[i, 'Traded as'])==True:
      wiki_data_extractor(i, "sellername")


      # May not be traded. once we do a stn_name_s we run the risk of
      # landing on a wiki page for a very generic item
      if _empty(df.loc[i, 'Traded as'])==True & _empty(df.loc[i, 'Headquarters'])==True:
        wiki_data_extractor(i, "sellername_second")

        if _empty(df.loc[i, 'Traded as'])==True & _empty(df.loc[i, 'Headquarters'])==True:
          wiki_data_extractor(i, "sellername")

        if _empty(df.loc[i, 'Traded as'])==True & _empty(df.loc[i, 'Headquarters'])==True:
          wiki_data_extractor(i, "sellername_first")


  if _empty(df.loc[i, 'Traded as'])==True & _empty(df.loc[i, 'Headquarters'])==True:
    gk_wiki_data_extractor(i, "sellername")

  if _empty(df.loc[i, 'Traded as'])==True & _empty(df.loc[i, 'Headquarters'])==True:
    gk_wiki_data_extractor(i, "sellername_second")


  # Update
  print(df.iloc[i])
  if (i!=0) & (i%10==0):
    print(df.iloc[i])
  # Introduce a pause every 100th iterations to circumvent HTTP error 429: Too Many Requests
  # Save also as a pickle
  if (i!=0) & (i%100==0):
    time.sleep(60)
    df.to_pickle("/content/drive/My Drive/OwnershipPatterns/data_out/" + OUTPUT_FILE_NAME)

  # Submit Knowledge Graph query

# Final pickle
df.to_pickle("/content/drive/My Drive/OwnershipPatterns/data_out/" + OUTPUT_FILE_NAME)
# Out:
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/purenergy
# google_score
# google_name                                          purenergy
# sellername                                       purenergy llc
# sellername_first                                     purenergy
# sellername_second                                purenergy llc
# Name: 157, dtype: object
# 158
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/quantum
# google_score
# google_name                                          quantum
# sellername                    quantum utility generation llc
# sellername_first                                     quantum
# sellername_second                            quantum utility
# Name: 158, dtype: object
# 159
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/quinnipiac
# google_score
# google_name                                          quinnipiac
# sellername                                quinnipiac energy llc
# sellername_first                                     quinnipiac
# sellername_second                             quinnipiac energy
# Name: 159, dtype: object
# 160
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url                https://en.wikipedia.org/wiki/quintana
# google_score
# google_name                                             quintana
# sellername             quintana infrastructure & development llc
# sellername_first                                        quintana
# sellername_second                        quintana infrastructure
# Name: 160, dtype: object
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url                https://en.wikipedia.org/wiki/quintana
# google_score
# google_name                                             quintana
# sellername             quintana infrastructure & development llc
# sellername_first                                        quintana
# sellername_second                        quintana infrastructure
# Name: 160, dtype: object
# 161
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Recycled_Energy_...
# google_score                                                   62.490395
# google_name                                  Recycled Energy Development
# sellername                               recycled energy development llc
# sellername_first                                                recycled
# sellername_second                                        recycled energy
# Name: 161, dtype: object
# 162
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets                                  US$30.9 billion (2017) [1]
# Area served
# Headquarters                                    Toronto, Ontario, Canada
# ISIN
# Traded as                                 NYSE: BEPNYSE: BEPCTSX: BEP.UN
# Type                                         Publicly traded partnership
# Parent                                       Brookfield Asset Management
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Brookfield_Renew...
# google_score                                                  1260.76062
# google_name                                Brookfield Renewable Partners
# sellername                                       renewable power & light
# sellername_first                                               renewable
# sellername_second                                        renewable power
# Name: 162, dtype: object
# 163
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/reservoir
# google_score
# google_name                                          reservoir
# sellername                         reservoir capital group llc
# sellername_first                                     reservoir
# sellername_second                            reservoir capital
# Name: 163, dtype: object
# 164
# Number of employees                                     45,000 (2022)[4]
# Total equity                                 US$51.432 billion (2021)[3]
# Operating income                             US$29.817 billion (2021)[3]
# Net income                                   US$22.575 billion (2021)[3]
# Total assets                                US$102.896 billion (2021)[3]
# Area served                                                    Worldwide
# Headquarters           London, United Kingdom (Global headquarters & ...
# ISIN
# Traded as              ASX: RIOLSE: RIONYSE: RIOFTSE 100 Index compon...
# Type                                                 Dual-listed company
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Rio_Tinto_(corpo...
# google_score                                                 13391.37207
# google_name                                                    Rio Tinto
# sellername                                              rio tinto plc/bp
# sellername_first                                                     rio
# sellername_second                                              rio tinto
# Name: 164, dtype: object
# 165
# Number of employees
# Total equity                         US$28,630 thousand (2010)[3]
# Operating income                    US$-21,340 thousand (2010)[2]
# Net income                          US$-22,680 thousand (2010)[2]
# Total assets                         US$11,940 thousand (2010)[3]
# Area served                               New York, United States
# Headquarters                       Tyngsboro, Massachusetts, U.S.
# ISIN
# Traded as                          OTC Pink No Information: BCONQ
# Type                                    Limited liability company
# Parent                                       RGA Investments, LLC
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Beacon_Power
# google_score                                             0.001853
# google_name                                          Beacon Power
# sellername                rockland capital energy investments llc
# sellername_first                                         rockland
# sellername_second                                rockland capital
# Name: 165, dtype: object
# 166
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/rockland
# google_score
# google_name                                          rockland
# sellername                               rockland capital llc
# sellername_first                                     rockland
# sellername_second                            rockland capital
# Name: 166, dtype: object
# 167
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/rockland
# google_score
# google_name                                          rockland
# sellername                                rockland capital lp
# sellername_first                                     rockland
# sellername_second                            rockland capital
# Name: 167, dtype: object
# 168
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Rocky_Mountains
# google_score                                             5033.527344
# google_name                                          Rocky Mountains
# sellername                                  rocky mountain power inc
# sellername_first                                               rocky
# sellername_second                                     rocky mountain
# Name: 168, dtype: object
# 169
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/sacramento
# google_score
# google_name                                          sacramento
# sellername                    sacramento cogeneration authority
# sellername_first                                     sacramento
# sellername_second                       sacramento cogeneration
# Name: 169, dtype: object
# 170
# Number of employees                                       20,000 (2018)
# Total equity              US$24.934 billion (Fiscal Year Ended 2020)[1]
# Operating income           US$2.833 billion (Fiscal Year Ended 2020)[1]
# Net income                 US$4.105 billion (Fiscal Year Ended 2020)[1]
# Total assets              US$66.623 billion (Fiscal Year Ended 2020)[1]
# Area served
# Headquarters                                San Diego, California, U.S.
# ISIN
# Traded as              NYSE: SREBMV: SREDJUA componentS&P 500 component
# Type                                                             Public
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url                         https://en.wikipedia.org/wiki/sempra
# google_score
# google_name                                                      sempra
# sellername                            sempra energy/riverstone holdings
# sellername_first                                                 sempra
# sellername_second                              sempra energy/riverstone
# Name: 170, dtype: object
# Number of employees                                       20,000 (2018)
# Total equity              US$24.934 billion (Fiscal Year Ended 2020)[1]
# Operating income           US$2.833 billion (Fiscal Year Ended 2020)[1]
# Net income                 US$4.105 billion (Fiscal Year Ended 2020)[1]
# Total assets              US$66.623 billion (Fiscal Year Ended 2020)[1]
# Area served
# Headquarters                                San Diego, California, U.S.
# ISIN
# Traded as              NYSE: SREBMV: SREDJUA componentS&P 500 component
# Type                                                             Public
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url                         https://en.wikipedia.org/wiki/sempra
# google_score
# google_name                                                      sempra
# sellername                            sempra energy/riverstone holdings
# sellername_first                                                 sempra
# sellername_second                              sempra energy/riverstone
# Name: 170, dtype: object
# 171
# Number of employees                                       20,000 (2018)
# Total equity              US$24.934 billion (Fiscal Year Ended 2020)[1]
# Operating income           US$2.833 billion (Fiscal Year Ended 2020)[1]
# Net income                 US$4.105 billion (Fiscal Year Ended 2020)[1]
# Total assets              US$66.623 billion (Fiscal Year Ended 2020)[1]
# Area served
# Headquarters                                San Diego, California, U.S.
# ISIN
# Traded as              NYSE: SREBMV: SREDJUA componentS&P 500 component
# Type                                                             Public
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url                         https://en.wikipedia.org/wiki/sempra
# google_score
# google_name                                                      sempra
# sellername                               sempra energyriverstone global
# sellername_first                                                 sempra
# sellername_second                               sempra energyriverstone
# Name: 171, dtype: object
# 172
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Signal_Hill,_Cal...
# google_score                                                 2155.714844
# google_name                                                  Signal Hill
# sellername                                         signal hill power llc
# sellername_first                                                  signal
# sellername_second                                            signal hill
# Name: 172, dtype: object
# 173
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/sithe
# google_score
# google_name                                          sithe
# sellername                              sithe energies inc
# sellername_first                                     sithe
# sellername_second                           sithe energies
# Name: 173, dtype: object
# 174
# Number of employees                                     13,599 (2013)[1]
# Total equity
# Operating income
# Net income
# Total assets
# Area served                       Central, Coastal & Southern California
# Headquarters                  2244 Walnut Grove Ave., Rosemead, CA 91770
# ISIN
# Traded as
# Type                                                          Subsidiary
# Parent                                              Edison International
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Southern_Califor...
# google_score                                                 2452.919678
# google_name                                   Southern California Edison
# sellername                                             southern power co
# sellername_first                                                southern
# sellername_second                                         southern power
# Name: 174, dtype: object
# 175
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/southwest
# google_score
# google_name                                          southwest
# sellername                                southwest generation
# sellername_first                                     southwest
# sellername_second                         southwest generation
# Name: 175, dtype: object
# 176
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Comanche_Peak_Nu...
# google_score                                                     0.00399
# google_name                            Comanche Peak Nuclear Power Plant
# sellername                         southwest generation operating co llc
# sellername_first                                               southwest
# sellername_second                                   southwest generation
# Name: 176, dtype: object
# 177
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters                   New York City, New York, United States
# ISIN
# Traded as
# Type                                                       Hedge fund
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Standard_General
# google_score                                              1160.384033
# google_name                                          Standard General
# sellername                                        standard general lp
# sellername_first                                             standard
# sellername_second                                    standard general
# Name: 177, dtype: object
# 178
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/stark
# google_score
# google_name                                          stark
# sellername                               stark investments
# sellername_first                                     stark
# sellername_second                        stark investments
# Name: 178, dtype: object
# 179
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/stark
# google_score
# google_name                                          stark
# sellername                            stark investments lp
# sellername_first                                     stark
# sellername_second                        stark investments
# Name: 179, dtype: object
# 180
# Number of employees                                  0 (2015)
# Total equity                            $1.299 billion (2015)
# Operating income                        $0.740 billion (2015)
# Net income                              $0.489 billion (2015)
# Total assets                            $8.266 billion (2015)
# Area served
# Headquarters                      Stamford, Connecticut, U.S.
# ISIN
# Traded as                                           NYSE: HOT
# Type                                               Subsidiary
# Parent
# Successor
# Fate                       Acquired by Marriott International
# Defunct                       September 23, 2016; 5 years ago
# Formerly
# google_url             https://en.wikipedia.org/wiki/starwood
# google_score
# google_name                                          starwood
# sellername                   starwood energy group global llc
# sellername_first                                     starwood
# sellername_second                             starwood energy
# Name: 180, dtype: object
# Number of employees                                  0 (2015)
# Total equity                            $1.299 billion (2015)
# Operating income                        $0.740 billion (2015)
# Net income                              $0.489 billion (2015)
# Total assets                            $8.266 billion (2015)
# Area served
# Headquarters                      Stamford, Connecticut, U.S.
# ISIN
# Traded as                                           NYSE: HOT
# Type                                               Subsidiary
# Parent
# Successor
# Fate                       Acquired by Marriott International
# Defunct                       September 23, 2016; 5 years ago
# Formerly
# google_url             https://en.wikipedia.org/wiki/starwood
# google_score
# google_name                                          starwood
# sellername                   starwood energy group global llc
# sellername_first                                     starwood
# sellername_second                             starwood energy
# Name: 180, dtype: object
# 181
# Number of employees                                  0 (2015)
# Total equity                            $1.299 billion (2015)
# Operating income                        $0.740 billion (2015)
# Net income                              $0.489 billion (2015)
# Total assets                            $8.266 billion (2015)
# Area served
# Headquarters                      Stamford, Connecticut, U.S.
# ISIN
# Traded as                                           NYSE: HOT
# Type                                               Subsidiary
# Parent
# Successor
# Fate                       Acquired by Marriott International
# Defunct                       September 23, 2016; 5 years ago
# Formerly
# google_url             https://en.wikipedia.org/wiki/starwood
# google_score
# google_name                                          starwood
# sellername                          starwood headquarters llc
# sellername_first                                     starwood
# sellername_second                       starwood headquarters
# Name: 181, dtype: object
# 182
# Number of employees                         21,126 (2021)[2]
# Total equity                      US$39.01 billion (2021)[2]
# Operating income                  US$33.66 billion (2021)[2]
# Net income                         US$8.58 billion (2021)[2]
# Total assets                     US$147.12 billion (2021)[2]
# Area served
# Headquarters                               Stavanger, Norway
# ISIN
# Traded as                                OSE: EQNRNYSE: EQNR
# Type                          State-ownedAllmennaksjeselskap
# Parent
# Successor
# Fate
# Defunct
# Formerly                          Statoil (until 15 May 2018
# google_url             https://en.wikipedia.org/wiki/statoil
# google_score
# google_name                                          statoil
# sellername                                statoil energy inc
# sellername_first                                     statoil
# sellername_second                             statoil energy
# Name: 182, dtype: object
# 183
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/STEAG
# google_score                                   1896.812378
# google_name                                          Steag
# sellername                                        steag ag
# sellername_first                                     steag
# sellername_second                                 steag ag
# Name: 183, dtype: object
# 184
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Suez_(company,_2...
# google_score                                                  3535.70459
# google_name                                                         SUEZ
# sellername                                                       suez sa
# sellername_first                                                    suez
# sellername_second                                                suez sa
# Name: 184, dtype: object
# 185
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters                                     Tokyo, Japan
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/sumitomo
# google_score
# google_name                                          sumitomo
# sellername                                      sumitomo corp
# sellername_first                                     sumitomo
# sellername_second                               sumitomo corp
# Name: 185, dtype: object
# 186
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/swec
# google_score
# google_name                                          swec
# sellername                                       swec llc
# sellername_first                                     swec
# sellername_second                                swec llc
# Name: 186, dtype: object
# 187
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/taft
# google_score
# google_name                                          taft
# sellername                        taft energy partners lp
# sellername_first                                     taft
# sellername_second                             taft energy
# Name: 187, dtype: object
# 188
# Number of employees
# Total equity
# Operating income
# Net income
# ...
# sellername                       upstate new york power producers inc
# sellername_first                                              upstate
# sellername_second                                         upstate new
# Name: 206, dtype: object
# 207
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Energy_Informati...
# google_score                                                 2256.822266
# google_name                            Energy Information Administration
# sellername                                        us energy partners llc
# sellername_first                                                      us
# sellername_second                                              us energy
# Name: 207, dtype: object
# 208
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/us
# google_score
# google_name                                          us
# sellername                       us power generating co
# sellername_first                                     us
# sellername_second                              us power
# Name: 208, dtype: object
# 209
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Mount_Vernon,_Ne...
# google_score                                                   335.87561
# google_name                                                 Mount Vernon
# sellername                                                   vernon city
# sellername_first                                                  vernon
# sellername_second                                            vernon city
# Name: 209, dtype: object
# 210
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Vero_Beach,_Florida
# google_score                                                 6597.796875
# google_name                                                   Vero Beach
# sellername                                               vero beach city
# sellername_first                                                    vero
# sellername_second                                             vero beach
# Name: 210, dtype: object
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/Vero_Beach,_Florida
# google_score                                                 6597.796875
# google_name                                                   Vero Beach
# sellername                                               vero beach city
# sellername_first                                                    vero
# sellername_second                                             vero beach
# Name: 210, dtype: object
# 211
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/walton
# google_score
# google_name                                          walton
# sellername                      walton electric member corp
# sellername_first                                     walton
# sellername_second                           walton electric
# Name: 211, dtype: object
# 212
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/wayzata
# google_score
# google_name                                          wayzata
# sellername                   wayzata investment partners llc
# sellername_first                                     wayzata
# sellername_second                         wayzata investment
# Name: 212, dtype: object
# 213
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/West_Valley_City...
# google_score                                                 1718.979858
# google_name                                             West Valley City
# sellername                                west valley power holdings llc
# sellername_first                                                    west
# sellername_second                                            west valley
# Name: 213, dtype: object
# 214
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/western
# google_score
# google_name                                          western
# sellername                   western generation partners llc
# sellername_first                                     western
# sellername_second                         western generation
# Name: 214, dtype: object
# 215
# Number of employees                                   8,000[1] (2017)
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters                               Milwaukee, Wisconsin, U.S.
# ISIN
# Traded as                                  NYSE: WECS&P 500 component
# Type                                                           Public
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/WEC_Energy_Group
# google_score                                             18659.912109
# google_name                                          WEC Energy Group
# sellername                                wisconsin electric power co
# sellername_first                                            wisconsin
# sellername_second                                  wisconsin electric
# Name: 215, dtype: object
# 216
# Number of employees
# Total equity
# Operating income
# Net income
# Total assets
# Area served
# Headquarters
# ISIN
# Traded as
# Type
# Parent
# Successor
# Fate
# Defunct
# Formerly
# google_url             https://en.wikipedia.org/wiki/wisvest
# google_score
# google_name                                          wisvest
# sellername                                      wisvest corp
# sellername_first                                     wisvest
# sellername_second                               wisvest corp
# Name: 216, dtype: object

# %%
df.to_excel("/content/drive/My Drive/OwnershipPatterns/data_out/" + OUTPUT_FILE_NAME + ".xlsx",
             sheet_name='Sheet_name_1')
